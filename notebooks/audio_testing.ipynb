# %% [markdown]
# # Audio Testing
#
# Use this notebook to test recording files and Whisper transcription workflows.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from config import DEFAULT_WHISPER_MODEL, RECORDINGS_DIR
from utils import get_latest_file

DEFAULT_WHISPER_MODEL, RECORDINGS_DIR
