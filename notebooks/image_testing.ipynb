# %% [markdown]
# # Image Testing
#
# Use this notebook to test image loading and multimodal model prompts.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from config import DEFAULT_MULTIMODAL_MODEL, IMAGES_DIR
from utils import load_image

DEFAULT_MULTIMODAL_MODEL, IMAGES_DIR
